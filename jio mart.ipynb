# %%
mart="jio"
cust_name="shaheena"
purchase="veg"
purchase_amount=2000
veg_amount=600
groc_amount=500
food_amount=900
if mart=="jio":
    print("this is mart",mart)
    if cust_name=="shaheena":
        print("this is customer",cust_name)
        if purchase=="veg":
            discount=0.50
            after_discount=veg_amount*discount
            veg_after=veg_amount-after_discount
            print("after_discount",veg_after)
        elif purchase=="groc":
            discount=0.30
            after_discount=groc_amount*discount
            groc_after=groc_amount-after_discount
            print("after_discount",groc_after)
        elif purchase=="food": 
            discount=0.35
            after_discount=food_amount*discount
            food_after=food_amount-after_discount
            print("after_discount",food_aftter)
        else:
            print("no available product")
    elif cust_name=="prasanna":
        if purchase=="veg":
            discount=0.20
            after_discount=veg_amount*discount
            veg_after=veg_amount-after_discount
            print("after_discount",veg_after)
        elif purchase=="groc":
            discount=0.10
            after_discount=groc_amount*discount
            groc_after=groc_amount-after_discount
            print("after_discount",groc_after)
        elif purchase=="food":
            discount=0.5
            after_discount=food_amount*discount
            food_after=food_amount-after_discount
            print("after_discount",food_after)
        else:
            print("no available product")
    elif cust_name=="swati":
        if purchase=="veg":
            discount=0.40
            after_discount=veg_amount*discount
            veg_after=veg_amount-after_discount
            print("after_discount",veg_after)
        elif purchase=="groc":
            discount=0.40
            after_discount=groc_amount*discount
            groc_after=groc_amount-after_discount
            print("after_discount",groc_after)
        elif purchase=="food":
            discount=0.25
            after_discount=food_amount*discount
            food_after=food_amount-after_discount
            print("after_discount",food_after)
        else:
            print("no available product")
    else:
        print("no customer available")

elif mart=="relaince":
    if cust_name=="prasanna":
        print("this is customer",cust_name)
        print("this is mart",mart)
        if purchase=="veg":
            discount=0.30
            after_discount=veg_amount*discount
            veg_after=veg_amount-after_discount
            print("after_discount",veg_after)
        elif purchase=="groc":
            discount=0.10
            after_discount=groc_amount*discount
            groc_after=groc_amount-after_discount
            print("after_discount",groc_after)
        elif purchase=="food": 
            discount=0.5
            after_discount=food_amount*discount
            food_after=food_amount-after_discount
            print("after_discount",food_aftter)
        else:
            print("no available product")
    elif cust_name=="shaheena":
        if purchase=="veg":
            discount=0.40
            after_discount=veg_amount*discount
            veg_after=veg_amount-after_discount
            print("after_discount",veg_after)
        elif purchase=="groc":
            discount=0.30
            after_discount=groc_amount*discount
            groc_after=groc_amount-after_discount
            print("after_discount",groc_after)
        elif purchase=="food":
            discount=0.25
            after_discount=food_amount*discount
            food_after=food_amount-after_discount
            print("after_discount",food_after)
        else:
            print("no available product")
    elif cust_name=="swati":
        if purchase=="veg":
            discount=0.50
            after_discount=veg_amount*discount
            veg_after=veg_amount-after_discount
            print("after_discount",veg_after)
        elif purchase=="groc":
            discount=0.20
            after_discount=groc_amount*discount
            groc_after=groc_amount-after_discount
            print("after_discount",groc_after)
        elif purchase=="food":
            discount=0.15
            after_discount=food_amount*discount
            food_after=food_amount-after_discount
            print("after_discount",food_after)
        else:
            print("no available product")
    else:
        print("no customer available")
else:
    print("no mart")
# Out:
# this is mart jio
# this is customer shaheena
# after_discount 300.0

# %%
mart="relaince"
cust_name="prasanna"
purchase="veg"
purchase_amount=1000
veg_amount=500
groc_amount=250
food_amount=250
if mart=="relaince":
    if cust_name=="prasanna":
        if purchase=="veg":
            discount=0.30
            after_discount=veg_amount*discount
            veg_after=veg_amount-after_discount
            print("after_discount",veg_after)
        elif purchase=="groc":
            discount=0.10
            after_discount=groc_amount*discount
            groc_after=groc_amount-after_discount
            print("after_discount",groc_after)
        elif purchase=="food":
            discount=0.5
            after_discount=food_amount*discount
            food_after=food_amount-after_discount
            print("after_discount",food_after)
        else:
            print("no product available")
    
    elif cust_name=="shaheena":
        if purchase=="veg":
            discount=0.40
            after_discount=veg_amount*discount
            veg_after=veg_amount-after_discount
            print("after_discount",veg_after)
        elif purchase=="groc":
            discount=0.30
            after_discount=groc_amount*discount
            groc_after=groc_amount-after_discount
            print("after_discount",groc_after)
        elif purchase=="food":
            discount=0.25
            after_discount=food_amount*discount
            food_after=food_amount-after_discount
            print("after_discount",food_after)
        else:
            print("no product available")
    elif cust_name=="swati":
        if purchase=="veg":
            discount=0.50
            after_discount=veg_amount*discount
            veg_after=veg_amount-after_discount
            print("after_discount",veg_after)
        elif purchase=="groc":
            discount=0.20
            after_discount=groc_amount*discount
            groc_after=groc_amount-after_discount
            print("after_discount",groc_after)
        elif purchase=="food":
            discount=0.15
            after_discount=food_amount*discount
            food_after=food_amount-after_discount
            print("after_discount",food_after)
        else:
            print("no product available")
    else:
        print("no customer available")
else:
    print("no mart available")
# Out:
# after_discount 350.0
